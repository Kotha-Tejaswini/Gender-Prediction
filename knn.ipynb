], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
def sensitivity(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tp / (tp + fn)
def specificity(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tn / (tn + fp)
def presicion(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tp / (tp + fp)
def balanced_accuracy(y_test, y_pred):
    return (specificity+sensitivity)/2

# %%
sensitivity = sensitivity(y_test, y_pred)
print(sensitivity)
specificity=specificity(y_test, y_pred)
print(specificity)
presicion=presicion(y_test, y_pred)
print(presicion)
balanced_accuracy=balanced_accuracy(y_test, y_pred)
print(balanced_accuracy)
# Out:
# 0.5348837209302325
# 0.6756756756756757
# 0.6571428571428571
# 0.605279698302954

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

model = KNeighborsClassifier(n_neighbors=3)

skf = StratifiedKFold(n_splits=10)
scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

for k, (train_index, test_index) in enumerate(skf.split(X_train, y_train)):
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
    
    model.fit(X_train_fold, Y_train_fold)
    y_pred = model.predict(X_test_fold)
    
    score = accuracy_score(Y_test_fold, y_pred)
    precision = precision_score(Y_test_fold, y_pred)
    recall = recall_score(Y_test_fold, y_pred)
    balanced_accuracy = balanced_accuracy_score(Y_test_fold, y_pred)
    f1 = f1_score(Y_test_fold, y_pred)
    confusion = confusion_matrix(Y_test_fold, y_pred)
    
    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)
    
    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d' % (k+1))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
        score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1
# Accuracy: 0.562, Precision: 0.625, Specificity: 0.571, Sensitivity: 0.556, Recall: 0.556
# Balanced Accuracy: 0.563, F1 Score: 0.588
# Confusion Matrix:
#  [[ 8  6]
#  [ 8 10]]
#
#
# Fold:  2
# Accuracy: 0.531, Precision: 0.588, Specificity: 0.500, Sensitivity: 0.556, Recall: 0.556
# Balanced Accuracy: 0.528, F1 Score: 0.571
# Confusion Matrix:
#  [[ 7  7]
#  [ 8 10]]
#
#
# Fold:  3
# Accuracy: 0.625, Precision: 0.688, Specificity: 0.643, Sensitivity: 0.611, Recall: 0.611
# Balanced Accuracy: 0.627, F1 Score: 0.647
# Confusion Matrix:
#  [[ 9  5]
#  [ 7 11]]
#
#
# Fold:  4
# Accuracy: 0.594, Precision: 0.611, Specificity: 0.533, Sensitivity: 0.647, Recall: 0.647
# Balanced Accuracy: 0.590, F1 Score: 0.629
# Confusion Matrix:
#  [[ 8  7]
#  [ 6 11]]
#
#
# Fold:  5
# Accuracy: 0.531, Precision: 0.545, Specificity: 0.333, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.520, F1 Score: 0.615
# Confusion Matrix:
#  [[ 5 10]
#  [ 5 12]]
#
#
# Fold:  6
# Accuracy: 0.562, Precision: 0.636, Specificity: 0.733, Sensitivity: 0.412, Recall: 0.412
# Balanced Accuracy: 0.573, F1 Score: 0.500
# Confusion Matrix:
#  [[11  4]
#  [10  7]]
#
#
# Fold:  7
# Accuracy: 0.438, Precision: 0.476, Specificity: 0.267, Sensitivity: 0.588, Recall: 0.588
# Balanced Accuracy: 0.427, F1 Score: 0.526
# Confusion Matrix:
#  [[ 4 11]
#  [ 7 10]]
#
#
# Fold:  8
# Accuracy: 0.500, Precision: 0.526, Specificity: 0.400, Sensitivity: 0.588, Recall: 0.588
# Balanced Accuracy: 0.494, F1 Score: 0.556
# Confusion Matrix:
#  [[ 6  9]
#  [ 7 10]]
#
#
# Fold:  9
# Accuracy: 0.688, Precision: 0.706, Specificity: 0.667, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.686, F1 Score: 0.706
# Confusion Matrix:
#  [[10  5]
#  [ 5 12]]
#
#
# Fold: 10
# Accuracy: 0.500, Precision: 0.522, Specificity: 0.267, Sensitivity: 0.706, Recall: 0.706
# Balanced Accuracy: 0.486, F1 Score: 0.600
# Confusion Matrix:
#  [[ 4 11]
#  [ 5 12]]
#
#
# Mean Accuracy: 0.553, Precision: 0.592, Specificity: 0.491, Sensitivity: 0.608, Recall: 0.608
# Mean Balanced Accuracy: 0.549, F1 Score: 0.594
# Mean Confusion Matrix:
#  [[ 7.2  7.5]
#  [ 6.8 10.5]]
#
#
# Cross-Validation Accuracy: 0.553 +/- 0.067

# %% [markdown]
# # Using test data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
dfm=pd.read_csv("dataset1.csv")

# %%
X_test = dfm.iloc[:,:-1]
y_test = dfm.iloc[:,-1]

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X,Y)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.49

# %%
from sklearn.metrics import confusion_matrix
m=confusion_matrix(y_test,y_pred)
m
# Out:
# array([[24, 36],
#        [15, 25]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
def sensitivity(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tp / (tp + fn)
def specificity(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tn / (tn + fp)
def presicion(y_test, y_pred):
    tp, fn, fp, tn = confusion_matrix(y_test, y_pred).ravel()
    return tp / (tp + fp)
def balanced_accuracy(y_test, y_pred):
    return (specificity+sensitivity)/2

# %%
sensitivity = sensitivity(y_test, y_pred)
print(sensitivity)
specificity=specificity(y_test, y_pred)
print(specificity)
presicion=presicion(y_test, y_pred)
print(presicion)
balanced_accuracy=balanced_accuracy(y_test, y_pred)
print(balanced_accuracy)
# Out:
# 0.4
# 0.625
# 0.6153846153846154
# 0.5125

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score, confusion_matrix

strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X, Y)

scores = []
precisions = []
specificities = []
sensitivities = []
recalls = []
balanced_accuracies = []
f1_scores = []
confusion_matrices = []

model = KNeighborsClassifier(n_neighbors=3)

for k, (train, test) in enumerate(kfold):
    model.fit(X.iloc[train], Y.iloc[train])
    y_pred = model.predict(X.iloc[test])
    score = accuracy_score(Y.iloc[test], y_pred)
    precision = precision_score(Y.iloc[test], y_pred)
    recall = recall_score(Y.iloc[test], y_pred)
    balanced_accuracy = balanced_accuracy_score(Y.iloc[test], y_pred)
    f1 = f1_score(Y.iloc[test], y_pred)
    confusion = confusion_matrix(Y.iloc[test], y_pred)

    scores.append(score)
    precisions.append(precision)
    recalls.append(recall)
    balanced_accuracies.append(balanced_accuracy)
    f1_scores.append(f1)
    confusion_matrices.append(confusion)

    tn, fp, fn, tp = confusion.ravel()
    specificity = tn / (tn + fp)
    specificities.append(specificity)
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

    print('Fold: %2d, Training/Test Split Distribution: %s' % (k + 1, np.bincount(Y.iloc[train])))
    print('Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    score, precision, specificity, sensitivity, recall))
    print('Balanced Accuracy: %.3f, F1 Score: %.3f' % (balanced_accuracy, f1))
    print('Confusion Matrix:\n', confusion)
    print('\n')

print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
mean_score = np.mean(scores)
mean_precision = np.mean(precisions)
mean_recall = np.mean(recalls)
mean_balanced_accuracy = np.mean(balanced_accuracies)
mean_f1 = np.mean(f1_scores)
mean_specificity = np.mean(specificities)
mean_sensitivity = np.mean(sensitivities)
mean_confusion = np.mean(confusion_matrices, axis=0)

print('Mean Accuracy: %.3f, Precision: %.3f, Specificity: %.3f, Sensitivity: %.3f, Recall: %.3f' % (
    mean_score, mean_precision, mean_specificity, mean_sensitivity, mean_recall))
print('Mean Balanced Accuracy: %.3f, F1 Score: %.3f' % (mean_balanced_accuracy, mean_f1))
print('Mean Confusion Matrix:\n', mean_confusion)
print('\n\nCross-Validation Accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold:  1, Training/Test Split Distribution: [171 189]
# Accuracy: 0.325, Precision: 0.385, Specificity: 0.158, Sensitivity: 0.476, Recall: 0.476
# Balanced Accuracy: 0.317, F1 Score: 0.426
# Confusion Matrix:
#  [[ 3 16]
#  [11 10]]
#
#
# Fold:  2, Training/Test Split Distribution: [171 189]
# Accuracy: 0.375, Precision: 0.429, Specificity: 0.158, Sensitivity: 0.571, Recall: 0.571
# Balanced Accuracy: 0.365, F1 Score: 0.490
# Confusion Matrix:
#  [[ 3 16]
#  [ 9 12]]
#
#
# Fold:  3, Training/Test Split Distribution: [171 189]
# Accuracy: 0.375, Precision: 0.400, Specificity: 0.368, Sensitivity: 0.381, Recall: 0.381
# Balanced Accuracy: 0.375, F1 Score: 0.390
# Confusion Matrix:
#  [[ 7 12]
#  [13  8]]
#
#
# Fold:  4, Training/Test Split Distribution: [171 189]
# Accuracy: 0.625, Precision: 0.714, Specificity: 0.789, Sensitivity: 0.476, Recall: 0.476
# Balanced Accuracy: 0.633, F1 Score: 0.571
# Confusion Matrix:
#  [[15  4]
#  [11 10]]
#
#
# Fold:  5, Training/Test Split Distribution: [171 189]
# Accuracy: 0.325, Precision: 0.393, Specificity: 0.105, Sensitivity: 0.524, Recall: 0.524
# Balanced Accuracy: 0.315, F1 Score: 0.449
# Confusion Matrix:
#  [[ 2 17]
#  [10 11]]
#
#
# Fold:  6, Training/Test Split Distribution: [171 189]
# Accuracy: 0.300, Precision: 0.294, Specificity: 0.368, Sensitivity: 0.238, Recall: 0.238
# Balanced Accuracy: 0.303, F1 Score: 0.263
# Confusion Matrix:
#  [[ 7 12]
#  [16  5]]
#
#
# Fold:  7, Training/Test Split Distribution: [171 189]
# Accuracy: 0.525, Precision: 0.562, Specificity: 0.632, Sensitivity: 0.429, Recall: 0.429
# Balanced Accuracy: 0.530, F1 Score: 0.486
# Confusion Matrix:
#  [[12  7]
#  [12  9]]
#
#
# Fold:  8, Training/Test Split Distribution: [171 189]
# Accuracy: 0.750, Precision: 0.677, Specificity: 0.474, Sensitivity: 1.000, Recall: 1.000
# Balanced Accuracy: 0.737, F1 Score: 0.808
# Confusion Matrix:
#  [[ 9 10]
#  [ 0 21]]
#
#
# Fold:  9, Training/Test Split Distribution: [171 189]
# Accuracy: 0.525, Precision: 0.750, Specificity: 0.947, Sensitivity: 0.143, Recall: 0.143
# Balanced Accuracy: 0.545, F1 Score: 0.240
# Confusion Matrix:
#  [[18  1]
#  [18  3]]
#
#
# Fold: 10, Training/Test Split Distribution: [171 189]
# Accuracy: 0.300, Precision: 0.267, Specificity: 0.421, Sensitivity: 0.190, Recall: 0.190
# Balanced Accuracy: 0.306, F1 Score: 0.222
# Confusion Matrix:
#  [[ 8 11]
#  [17  4]]
#
#
#
#
# Cross-Validation Accuracy: 0.443 +/- 0.148
# Mean Accuracy: 0.443, Precision: 0.487, Specificity: 0.442, Sensitivity: 0.443, Recall: 0.443
# Mean Balanced Accuracy: 0.442, F1 Score: 0.435
# Mean Confusion Matrix:
#  [[ 8.4 10.6]
#  [11.7  9.3]]
#
#
# Cross-Validation Accuracy: 0.443 +/- 0.148
